# %%
import sys
from pathlib import Path

# Force notebook to recognize project root
import os
ROOT = Path(os.getcwd()).resolve().parents[0] # one level up from tests/
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

import pandas as pd
from src.inference_pipeline.inference import predict

# Load a few rows of already preprocessed data
sample_path = ROOT / "data/processed/cleaning_eval.csv"
df = pd.read_csv(sample_path).sample(5, random_state=42).reset_index(drop=True)

print("Input sample:")
display(df.head())

# Run inference
preds_df = predict(df)
print("✅ Predictions returned")
display(preds_df[["predicted_price"]].head())
# Out:
# 📂 Inference using project root: /Users/venkatj/Projects/Regression_ML_EndtoEnd
# Input sample:
#          date  median_sale_price  median_list_price  median_ppsf  \
# 0  2020-02-29           264250.0           274900.0   113.389951
# 1  2021-09-30           275000.0           310000.0   149.870801
# 2  2021-01-31           682000.0           639450.0   295.024552
# 3  2020-06-30           357500.0           349950.0   166.427889
# 4  2020-02-29           432250.0           369900.0   193.543755
#
#    median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 0        118.679358         6.0            8.0           9.0       20.0
# 1        148.302551       269.0          326.0         383.0      147.0
# 2        302.377394        56.0           49.0          48.0       53.0
# 3        171.774206        58.0           68.0          74.0       84.0
# 4        199.298579        30.0           30.0          30.0       45.0
#
#    median_dom  ...  Median Home Value  Total Labor Force  \
# 0        57.0  ...           164200.0             1800.0
# 1        10.0  ...           168800.0            23871.0
# 2        48.0  ...           581400.0             8095.0
# 3        79.0  ...           230500.0             7613.0
# 4       110.5  ...           315100.0             1410.0
#
#    Unemployed Population Total School Age Population  Total School Enrollment  \
# 0                   42.0                      4107.0                   4107.0
# 1                 1089.0                     44359.0                  44359.0
# 2                  322.0                     15414.0                  15414.0
# 3                  974.0                     17089.0                  17089.0
# 4                   51.0                      2464.0                   2464.0
#
#    Median Commute Time          price                             city_full  \
# 0               1567.0  242726.863024       Dallas-Fort Worth-Arlington, TX
# 1              21394.0  260872.726680     Atlanta-Sandy Springs-Roswell, GA
# 2               7065.0  644178.953136    New York-Newark-Jersey City, NY-NJ
# 3               6023.0  298381.733230  Riverside-San Bernardino-Ontario, CA
# 4               1199.0  375099.668300          Denver-Aurora-Centennial, CO
#
#        lat       lng
# 0  32.8495  -96.9704
# 1  33.7338  -84.3922
# 2  40.7222  -74.0225
# 3  34.5517 -116.1297
# 4  39.4337 -104.8944
#
# [5 rows x 41 columns]
# ⚠️ Skipping lat/lng merge: already present in DataFrame.
# ✅ Dropped 0 duplicate rows (excluding date/year).
# ✅ Removed 0 rows with median_list_price > 19M.
# ✅ Predictions returned
#    predicted_price
# 0      296944.8125
# 1      280072.3750
# 2      567519.0625
# 3      370770.6875
# 4      391739.9375
